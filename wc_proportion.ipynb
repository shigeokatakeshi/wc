# %%
pip install openpyxl
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 242.1/242.1 kB 2.9 MB/s eta 0:00:003.3 MB/s eta 0:00:01
# ...
#
# [notice] A new release of pip available: 22.2.1 -> 22.3.1
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
from time import sleep
import pandas as pd
import openpyxl

# %%
pd.read_excel("ws_proportion.xlsx")
# Out:
# /Users/satoutakeshi/camp2/week03/wc/.venv/lib/python3.10/site-packages/openpyxl/styles/stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
#    BIS Statistics Explorer                                         Unnamed: 1  \
# 0              Table D11.3  Turnover of OTC foreign exchange instruments, ...
# 1                      NaN  "Net-net" basis, April 1989-2022 daily average...
# 2                  Dataset   Triennial OTC derivatives statistics (TRIENNIAL)
# 3             Data updated                                  '25/10/2022 08:12
# 4                 Data URL  http://stats.bis.org:8089/statx/srs/table/d11....
# 5                      NaN                                                NaN
# 6                 Currency                                               1989
# 7                      NaN                                             Amount
# ...
